# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/drive/MyDrive/only.data/onlinefoods.csv")

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Marital Status                 object
# Occupation                     object
# Monthly Income                 object
# Educational Qualifications     object
# Family size                     int64
# latitude                      float64
# longitude                     float64
# Pin code                        int64
# Output                         object
# Feedback                       object
# Unnamed: 12                    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
df["Age"].value_counts()
# Out:
# Age
# 23    73
# 22    57
# 25    52
# 24    50
# 26    35
# 21    23
# 27    21
# 32    16
# 28    15
# 29    14
# 20     9
# 30     9
# 31     8
# 19     4
# 18     1
# 33     1
# Name: count, dtype: int64

# %%
df["Age"]=df["Age"].astype(int)

# %%
#based on gender
sns.countplot(x="Gender",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Age",data=df,hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Feedback",data=df,hue="Gender")
# Out:
# <Axes: xlabel='Feedback', ylabel='count'>

# %%
sns.countplot(x="Marital Status",data=df,hue="Gender")
# Out:
# <Axes: xlabel='Marital Status', ylabel='count'>

# %%
sns.barplot(x=df["Pin code"].value_counts().nlargest(5).index,y=df["Pin code"].value_counts().nlargest(5).values)
# Out:
# <Axes: xlabel='Pin code'>

# %%
ff=df["Pin code"].value_counts().nlargest(5)
pd.DataFrame(ff)
sns.barplot(x=ff.index,y=ff.values)
# Out:
# <Axes: xlabel='Pin code'>

# %%
df.groupby(["Gender","Marital Status"]).agg({"Feedback":"value_counts"}).unstack().transpose().plot(kind="bar")
# Out:
# <Axes: xlabel='None,Feedback'>

# %%
df["Pin code"].value_counts().nlargest(5).plot(kind="bar")
# Out:
# <Axes: xlabel='Pin code'>

# %%
df.groupby(["Gender","Marital Status"]).agg({"Feedback":"value_counts"})
# Out:
#                                     Feedback
# Gender Marital Status    Feedback
# Female Married           Positive         36
#                          Negative         13
#        Prefer not to say Negative          3
#                          Positive          2
#        Single            Positive        101
#                          Negative         11
# Male   Married           Positive         41
#                          Negative         18
#        Prefer not to say Positive          5
#                          Negative          2
#        Single            Positive        132
#                          Negative         24
